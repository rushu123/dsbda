# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %%
ds=pd.notnull(df)
ds
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df.fillna(0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.fillna(0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.fillna(method='pad')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15032\196241153.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       71.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15032\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       99.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       84.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df["Subject 1"].fillna(85,inplace=True)
df["Subject 2"].fillna(95,inplace=True)
df["Subject 3"].fillna(85,inplace=True)
df["Subject 4"].fillna(95,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       85.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df['Subject 1'].fillna(df['Subject 1'].mean(),inplace=True)
df['Subject 2'].fillna(df['Subject 2'].mean(),inplace=True)
df['Subject 3'].fillna(df['Subject 3'].mean(),inplace=True)
df['Subject 4'].fillna(df['Subject 4'].mean(),inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
nc=['Subject 1','Subject 2','Subject 3','Subject 4']
for col in nc:
    df[col].fillna(df[col].mean(),inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.replace(to_replace=np.nan,value=85)
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 1          2     Student_2       72.0       97.0       82.0       85.0
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 3          4     Student_4       72.0       99.0       85.0       84.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log1_sub4
# 0            96   4.532599
# 1            78  85.000000
# 2           -94   4.605170
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.interpolate(method='linear',limit_direction='forward')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15032\4126225218.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear',limit_direction='forward')
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.5
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       77.5       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(how='all',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(how='any',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(axis=0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(axis=0,how='any',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(axis=0,how='all',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(axis=1,how='all',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.dropna(axis=1,how='any',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Attendance
# 0           1     Student_1        100         62          96
# 1           2     Student_2         72         97          78
# 2           3     Student_3        100         88         -94
# 3           4     Student_4         72         99          86
# 4           5     Student_5         97         70          86
# ...       ...           ...        ...        ...         ...
# 996       997   Student_997         88         68          98
# 997       998   Student_998         61         96          83
# 998       999   Student_999         72         76          90
# 999      1000  Student_1000         68         87          79
# 1000        1     Student_1        100         62          96
#
# [1001 rows x 5 columns]

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#add negative data

# %%
df[df[['Subject 1','Subject 2','Subject 3','Subject 4']]<0]
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df[['Subject 1', 'Subject 2', 'Subject 3','Subject 4']] = df[['Subject 1', 'Subject 2', 'Subject 3','Subject 4']].clip(lower=0)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#add duplicate data

# %%
df = pd.read_csv('A1.csv') 
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 1          2     Student_2         72         97       82.0        NaN
# 2          3     Student_3        100         88       71.0       99.0
# 3          4     Student_4         72         99        NaN       84.0
# 4          5     Student_5         97         70       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 1            78
# 2           -94
# 3            86
# 4            86
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nc = ['Subject 1', 'Subject 2', 'Subject 3','Subject 4']
for col in nc:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
for col in nc:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = np.where((df[col] < lower_bound) | (df[col] > upper_bound), df[col].median(), df[col])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 1          2     Student_2       72.0       97.0       82.0        NaN
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 3          4     Student_4       72.0       99.0        NaN       84.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance
# 0            96
# 1            78
# 2           -94
# 3            86
# 4            86
# ...

# %%
# Assuming 'df' is your DataFrame
df['log1_sub4'] = np.log1p(df['Subject 4'])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 1          2     Student_2       72.0       97.0       82.0        NaN
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 3          4     Student_4       72.0       99.0        NaN       84.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log1_sub4
# 0            96   4.532599
# 1            78        NaN
# 2           -94   4.605170
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the CSV file into a DataFrame
df = pd.read_csv('A1.csv')

# Extract relevant columns
grades = df[['Roll No', 'Subject 1', 'Subject 2', 'Subject 3', 'Subject 4', 'Attendance']]

# Plot Histograms
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Histograms for Subject Grades and Attendance', y=0.95)
for i, col in enumerate(grades.columns[1:]):  # Exclude 'Roll No'
    ax = axes.flatten()[i]
    ax.hist(grades[col], bins=20, color='skyblue', edgecolor='black')
    ax.set_title(f'{col} Histogram')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Q-Q plot
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Q-Q Plots for Subject Grades and Attendance', y=0.98)
for i, col in enumerate(grades.columns[1:]):  # Exclude 'Roll No'
    ax = axes.flatten()[i]
    sorted_data = np.sort(grades[col])
    theoretical_quantiles = np.percentile(sorted_data, np.linspace(0, 100, len(sorted_data)))
    ax.plot(theoretical_quantiles, np.sort(grades[col]), marker='o', linestyle='None', color='blue')
    ax.plot([np.min(sorted_data), np.max(sorted_data)], [np.min(sorted_data), np.max(sorted_data)], linestyle='--', color='red')
    ax.set_title(f'{col} Q-Q Plot')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# KDE plot
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Kernel Density Estimation Plots for Subject Grades and Attendance', y=0.98)
for i, col in enumerate(grades.columns[1:]):  # Exclude 'Roll No'
    ax = axes.flatten()[i]
    sns.kdeplot(grades[col], ax=ax, fill=True, color='skyblue', linewidth=2)
    ax.set_title(f'{col} KDE Plot')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Skewness and z-score
skewness = grades.skew()
z_scores = (grades - grades.mean()) / grades.std()

# Display results
print("Skewness:")
print(skewness)
print("\nZ-Scores:")
print(z_scores)
# Out:
# Skewness:
# Roll No       0.000021
# Subject 1     0.091410
# Subject 2    -0.010696
# Subject 3     0.006017
# Subject 4    -0.068298
# Attendance   -5.348146
# dtype: float64
#
# Z-Scores:
#        Roll No  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0    -1.726012   1.718218  -1.517511  -0.597082   0.971282    1.029784
# 1    -1.722553  -0.598529   1.422599   0.182851        NaN   -0.721646
# 2    -1.719094   1.718218   0.666570  -0.770400   1.564820  -17.457528
# 3    -1.715635  -0.598529   1.590605        NaN   0.292953    0.056767
# 4    -1.712176   1.469995  -0.845486   0.356169  -0.894122    0.056767
# ...        ...        ...        ...        ...        ...         ...
# 996   1.719087   0.725327  -1.013492   0.356169  -1.233287    1.224387
# 997   1.722546  -1.508679   1.338595  -1.550333   0.292953   -0.235138
# 998   1.726005  -0.598529  -0.341467   0.876124  -0.724540    0.445974
# 999   1.729464  -0.929493   0.582567   1.742716  -0.385376   -0.624344
# ...

# %%
nc = df[['Roll No', 'Subject 1', 'Subject 2', 'Subject 3', 'Subject 4', 'Attendance']]
skewness = nc.skew()
z_scores = (nc - nc.mean()) / nc.std()
print("Skewness:")
print(skewness)
print("\nZ-Scores:")
print(z_scores)
# Out:
# Skewness:
# Roll No       0.000021
# Subject 1     0.091410
# Subject 2    -0.010696
# Subject 3     0.006020
# Subject 4    -0.068332
# Attendance   -5.348146
# dtype: float64
#
# Z-Scores:
#        Roll No  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0    -1.726012   1.718218  -1.517511  -0.597381   0.971768    1.029784
# 1    -1.722553  -0.598529   1.422599   0.182942   0.000000   -0.721646
# 2    -1.719094   1.718218   0.666570  -0.770786   1.565603  -17.457528
# 3    -1.715635  -0.598529   1.590605   0.000000   0.293100    0.056767
# 4    -1.712176   1.469995  -0.845486   0.356348  -0.894570    0.056767
# ...        ...        ...        ...        ...        ...         ...
# 996   1.719087   0.725327  -1.013492   0.356348  -1.233904    1.224387
# 997   1.722546  -1.508679   1.338595  -1.551109   0.293100   -0.235138
# 998   1.726005  -0.598529  -0.341467   0.876563  -0.724903    0.445974
# 999   1.729464  -0.929493   0.582567   1.743588  -0.385568   -0.624344
# ...
