# %%
import pandas as pd

# %%
df=pd.read_csv('dirtydata.csv')
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127    -300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.shape
# Out:
# (32, 5)

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  266.013333
# std     70.039591    7.832933   12.998759  164.876415
# min     30.000000   90.000000  101.000000 -300.000000
# 25%     60.000000  100.000000  120.000000  247.000000
# 50%     60.000000  102.500000  127.500000  282.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df['Calories']=df['Calories'].abs()
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
x=df['Calories'].mean()
x
# Out:
# 304.68

# %%
#fill the null value with calculate mean value
df['Calories'].fillna(x, inplace=True)
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# 6         60  2020/12/07'    110       136    374.00
# 7        450  2020/12/08'    104       134    253.30
# 8         30  2020/12/09'    109       133    195.10
# 9         60  2020/12/10'     98       124    269.00
# 10        60  2020/12/11'    103       147    329.30
# 11        60  2020/12/12'    100       120    250.70
# 12        60  2020/12/12'    100       120    250.70
# 13        60  2020/12/13'    106       128    345.30
# 14        60  2020/12/14'    104       132    379.30
# 15        60  2020/12/15'     98       123    275.00
# 16        60  2020/12/16'     98       120    215.20
# ...

# %%
#fill the null value with calculate mean value
df['Calories'].fillna(x, inplace=True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
# Convert the date into a "Date" format
# df['Date'] = pd.to_datetime(df['Date'], format='mixed')
# print(df)
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
print(df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
#drop null value of date column
#inplace used to store the value after performing any actions
# df.dropna(subset=['Date'], inplace=True)
# df

# %%
#7th location has value 450 for duration which is an outlier, so replace it with a specified value i.e 45
df.loc[7, 'Duration']=45
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
#find duplicate data
# sum of duplicated values-> df.duplicated().sum()
df.duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
#drop the duplicate values
df.drop_duplicates(inplace=True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
import pandas as pd
data=pd.read_csv("nba.csv") #read dataset it shuould be in same dire
print(data)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
data['Position'].replace(['SG', 'PF', 'PG', 'SF', 'C'], [1, 2, 3, 4, 5], inplace=True)
data
# Out:
#               Name            Team  Number  Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0         3   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99         4   25   6-Jun     235
# 2     John Holland  Boston Celtics      30         1   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28         1   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8         2   29  10-Jun     231
# ..             ...             ...     ...       ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41         2   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8         3   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25         3   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21         5   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24         5   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
category=pd.cut(data.Age,bins=[19,25,30,35,45],labels=['A','B','C','D'])
data.insert(5,'Age_group',category)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4924\2514097606.py in ?()
#       1 category=pd.cut(data.Age,bins=[19,25,30,35,45],labels=['A','B','C','D'])
# ----> 2 data.insert(5,'Age_group',category)
#       3 data
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4930                 "'self.flags.allows_duplicate_labels' is False."
#    4931             )
#    4932         if not allow_duplicates and column in self.columns:
#    4933             # Should this be a different kind of error??
# -> 4934             raise ValueError(f"cannot insert {column}, already exists")
#    4935         if not is_integer(loc):
#    4936             raise TypeError("loc must be int")
#    4937         # convert non stdlib ints to satisfy typing checks
#
# ...
